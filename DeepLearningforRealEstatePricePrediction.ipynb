# %% [markdown]
# # TASK #1: UNDERSTAND THE PROBLEM STATEMENT AND BUSINESS CASE

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # TASK #2: IMPORT LIBRARIES AND DATASETS

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


from jupyterthemes import jtplot
jtplot.style(theme='monokai', context='notebook', ticks=True, grid=False) 
# setting the style of the notebook to be monokai theme  
# this line of code is important to ensure that we are able to see the x and y axes clearly
# If you don't run this code line, you will notice that the xlabel and ylabel on any plot is black on black and it will be hard to see them.

# %%
house_df = pd.read_csv('realestate_prices.csv', encoding = 'ISO-8859-1')

# %%
house_df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# 1             2570      7242     2.0           0     0  ...      7
# 2              770     10000     1.0           0     0  ...      6
# 3             1960      5000     1.0           0     0  ...      7
# 4             1680      8080     1.0           0     0  ...      8
# ...            ...       ...     ...         ...   ...  ...    ...
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 0            1180              0      1955             0    98178  47.5112
# 1            2170            400      1951          1991    98125  47.7210
# 2             770              0      1933             0    98028  47.7379
# 3            1050            910      1965             0    98136  47.5208
# 4            1680              0      1987             0    98074  47.6168
# ...           ...            ...       ...           ...      ...      ...
# 21608        1530              0      2009             0    98103  47.6993
# 21609        2310              0      2014             0    98146  47.5107
# 21610        1020              0      2009             0    98144  47.5944
# 21611        1600              0      2004             0    98027  47.5345
# 21612        1020              0      2008             0    98144  47.5941
#
#           long  sqft_living15  sqft_lot15
# 0     -122.257           1340        5650
# 1     -122.319           1690        7639
# 2     -122.233           2720        8062
# 3     -122.393           1360        5000
# 4     -122.045           1800        7503
# ...        ...            ...         ...
# 21608 -122.346           1530        1509
# 21609 -122.362           1830        7200
# 21610 -122.299           1020        2007
# 21611 -122.069           1410        1287
# 21612 -122.299           1020        1357
#
# [21613 rows x 21 columns]

# %%
house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
#  17  lat            21613 non-null  float64
#  18  long           21613 non-null  float64
#  19  sqft_living15  21613 non-null  int64
#  20  sqft_lot15     21613 non-null  int64
# dtypes: float64(5), int64(15), object(1)
# memory usage: 3.5+ MB

# %% [markdown]
# **PRACTICE OPPORTUNITY #1 [OPTIONAL]:**
# - **What is the average house price?**
# - **What is the price of the cheapest house?**
# - **What is the average number of bathrooms and bedrooms? round your answer to the lowest value**
# - **What is the maximum number of bedrooms?**

# %%
house_df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# std    4.142051e+04      0.539989      0.086517      0.766318      0.650743
# min    5.200000e+02      1.000000      0.000000      0.000000      1.000000
# 25%    5.040000e+03      1.000000      0.000000      0.000000      3.000000
# 50%    7.618000e+03      1.500000      0.000000      0.000000      3.000000
# 75%    1.068800e+04      2.000000      0.000000      0.000000      4.000000
# max    1.651359e+06      3.500000      1.000000      4.000000      5.000000
#
#               grade    sqft_above  sqft_basement      yr_built  yr_renovated  \
# count  21613.000000  21613.000000   21613.000000  21613.000000  21613.000000
# mean       7.656873   1788.390691     291.509045   1971.005136     84.402258
# std        1.175459    828.090978     442.575043     29.373411    401.679240
# min        1.000000    290.000000       0.000000   1900.000000      0.000000
# 25%        7.000000   1190.000000       0.000000   1951.000000      0.000000
# 50%        7.000000   1560.000000       0.000000   1975.000000      0.000000
# 75%        8.000000   2210.000000     560.000000   1997.000000      0.000000
# max       13.000000   9410.000000    4820.000000   2015.000000   2015.000000
#
#             zipcode           lat          long  sqft_living15     sqft_lot15
# count  21613.000000  21613.000000  21613.000000   21613.000000   21613.000000
# mean   98077.939805     47.560053   -122.213896    1986.552492   12768.455652
# std       53.505026      0.138564      0.140828     685.391304   27304.179631
# min    98001.000000     47.155900   -122.519000     399.000000     651.000000
# 25%    98033.000000     47.471000   -122.328000    1490.000000    5100.000000
# 50%    98065.000000     47.571800   -122.230000    1840.000000    7620.000000
# 75%    98118.000000     47.678000   -122.125000    2360.000000   10083.000000
# max    98199.000000     47.777600   -121.315000    6210.000000  871200.000000

# %% [markdown]
# # TASK #3: PERFORM DATA VISUALIZATION

# %%
sns.scatterplot(x='sqft_living', y='price', data=house_df)
# Out:
# <AxesSubplot: xlabel='sqft_living', ylabel='price'>

# %%
house_df.hist(bins=20, figsize=(20,30), color='b')
# Out:
# array([[<AxesSubplot: title={'center': 'id'}>,
#         <AxesSubplot: title={'center': 'price'}>,
#         <AxesSubplot: title={'center': 'bedrooms'}>,
#         <AxesSubplot: title={'center': 'bathrooms'}>],
#        [<AxesSubplot: title={'center': 'sqft_living'}>,
#         <AxesSubplot: title={'center': 'sqft_lot'}>,
#         <AxesSubplot: title={'center': 'floors'}>,
#         <AxesSubplot: title={'center': 'waterfront'}>],
#        [<AxesSubplot: title={'center': 'view'}>,
#         <AxesSubplot: title={'center': 'condition'}>,
#         <AxesSubplot: title={'center': 'grade'}>,
#         <AxesSubplot: title={'center': 'sqft_above'}>],
#        [<AxesSubplot: title={'center': 'sqft_basement'}>,
#         <AxesSubplot: title={'center': 'yr_built'}>,
#         <AxesSubplot: title={'center': 'yr_renovated'}>,
#         <AxesSubplot: title={'center': 'zipcode'}>],
#        [<AxesSubplot: title={'center': 'lat'}>,
#         <AxesSubplot: title={'center': 'long'}>,
#         <AxesSubplot: title={'center': 'sqft_living15'}>,
#         <AxesSubplot: title={'center': 'sqft_lot15'}>]], dtype=object)

# %%
f, ax = plt.subplots(figsize = (20, 20))
sns.heatmap(house_df.corr(), annot = True)
# Out:
# <AxesSubplot: >

# %%
house_df_sample = house_df[ ['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'sqft_above', 'sqft_basement', 'yr_built']   ]

# %%
house_df_sample
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  sqft_above  \
# 0      221900.0         3       1.00         1180      5650        1180
# 1      538000.0         3       2.25         2570      7242        2170
# 2      180000.0         2       1.00          770     10000         770
# 3      604000.0         4       3.00         1960      5000        1050
# 4      510000.0         3       2.00         1680      8080        1680
# ...         ...       ...        ...          ...       ...         ...
# 21608  360000.0         3       2.50         1530      1131        1530
# 21609  400000.0         4       2.50         2310      5813        2310
# 21610  402101.0         2       0.75         1020      1350        1020
# 21611  400000.0         3       2.50         1600      2388        1600
# 21612  325000.0         2       0.75         1020      1076        1020
#
#        sqft_basement  yr_built
# 0                  0      1955
# 1                400      1951
# 2                  0      1933
# 3                910      1965
# 4                  0      1987
# ...              ...       ...
# 21608              0      2009
# 21609              0      2014
# 21610              0      2009
# 21611              0      2004
# 21612              0      2008
#
# [21613 rows x 8 columns]

# %% [markdown]
# **PRACTICE OPPORTUNITY #2 [OPTIONAL]:**
# - **Using Seaborn, plot the pairplot for the features contained in "house_df_sample"**
# - **Explore the data and perform sanity check**

# %%
sns.pairplot(house_df_sample)

# %% [markdown]
# # TASK #4: PERFORM DATA CLEANING AND FEATURE ENGINEERING

# %%
selected_features = ['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'sqft_above', 'sqft_basement']

# %%
X = house_df[selected_features]

# %%
X
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  sqft_above  \
# 0             3       1.00         1180      5650     1.0        1180
# 1             3       2.25         2570      7242     2.0        2170
# 2             2       1.00          770     10000     1.0         770
# 3             4       3.00         1960      5000     1.0        1050
# 4             3       2.00         1680      8080     1.0        1680
# ...         ...        ...          ...       ...     ...         ...
# 21608         3       2.50         1530      1131     3.0        1530
# 21609         4       2.50         2310      5813     2.0        2310
# 21610         2       0.75         1020      1350     2.0        1020
# 21611         3       2.50         1600      2388     2.0        1600
# 21612         2       0.75         1020      1076     2.0        1020
#
#        sqft_basement
# 0                  0
# 1                400
# 2                  0
# 3                910
# 4                  0
# ...              ...
# 21608              0
# 21609              0
# 21610              0
# 21611              0
# 21612              0
#
# [21613 rows x 7 columns]

# %%
y = house_df['price']

# %%
y
# Out:
# 0        221900.0
# 1        538000.0
# 2        180000.0
# 3        604000.0
# 4        510000.0
#            ...
# 21608    360000.0
# 21609    400000.0
# 21610    402101.0
# 21611    400000.0
# 21612    325000.0
# Name: price, Length: 21613, dtype: float64

# %%
X.shape
# Out:
# (21613, 7)

# %%
y.shape
# Out:
# (21613,)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_scaled
# Out:
# array([[0.09090909, 0.125     , 0.06716981, ..., 0.        , 0.09758772,
#         0.        ],
#        [0.09090909, 0.28125   , 0.17207547, ..., 0.4       , 0.20614035,
#         0.08298755],
#        [0.06060606, 0.125     , 0.03622642, ..., 0.        , 0.05263158,
#         0.        ],
#        ...,
#        [0.06060606, 0.09375   , 0.05509434, ..., 0.4       , 0.08004386,
#         0.        ],
#        [0.09090909, 0.3125    , 0.09886792, ..., 0.4       , 0.14364035,
#         0.        ],
#        [0.06060606, 0.09375   , 0.05509434, ..., 0.4       , 0.08004386,
#         0.        ]])

# %%
X_scaled.shape
# Out:
# (21613, 7)

# %%
scaler.data_max_
# Out:
# array([3.300000e+01, 8.000000e+00, 1.354000e+04, 1.651359e+06,
#        3.500000e+00, 9.410000e+03, 4.820000e+03])

# %%
scaler.data_min_
# Out:
# array([  0.,   0., 290., 520.,   1., 290.,   0.])

# %%
y = y.values.reshape(-1,1)

# %%
y_scaled = scaler.fit_transform(y)

# %%
y_scaled
# Out:
# array([[0.01926557],
#        [0.06072131],
#        [0.01377049],
#        ...,
#        [0.04289849],
#        [0.04262295],
#        [0.03278689]])

# %% [markdown]
# # TASK #5: TRAIN A DEEP LEARNING MODEL WITH LIMITED NUMBER OF FEATURES

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.25)

# %%
X_train.shape
# Out:
# (16209, 7)

# %%
X_test.shape
# Out:
# (5404, 7)

# %%
import tensorflow.keras
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense
 
model = Sequential()
model.add(Dense(100, input_dim=7, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(200, activation='relu'))
model.add(Dense(1, activation='linear'))

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_27 (Dense)            (None, 100)               800
#
#  dense_28 (Dense)            (None, 100)               10100
#
#  dense_29 (Dense)            (None, 100)               10100
#
#  dense_30 (Dense)            (None, 200)               20200
#
#  dense_31 (Dense)            (None, 1)                 201
#
# =================================================================
# Total params: 41,401
# Trainable params: 41,401
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = 'Adam', loss = 'mean_squared_error')

# %%
epochs_hist = model.fit(X_train, y_train, epochs = 100, batch_size = 50, validation_split = 0.2)
# Out:
# Epoch 1/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 2/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 3/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0011 - val_loss: 9.9744e-04
# Epoch 4/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0011 - val_loss: 9.6786e-04
# Epoch 5/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0011 - val_loss: 9.3991e-04
# Epoch 6/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0011 - val_loss: 9.5007e-04
# Epoch 7/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0011 - val_loss: 9.4141e-04
# Epoch 8/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 9/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 10/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 11/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0011 - val_loss: 9.4600e-04
# Epoch 12/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 13/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0010 - val_loss: 9.5527e-04
# Epoch 14/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0010 - val_loss: 9.3855e-04
# Epoch 15/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 16/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0010 - val_loss: 9.7600e-04
# Epoch 17/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0010 - val_loss: 9.9189e-04
# Epoch 18/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0010 - val_loss: 9.3835e-04
# Epoch 19/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 20/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0010 - val_loss: 9.6697e-04
# Epoch 21/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0010 - val_loss: 9.5608e-04
# Epoch 22/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0010 - val_loss: 9.2309e-04
# Epoch 23/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 24/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0010 - val_loss: 9.4560e-04
# Epoch 25/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0010 - val_loss: 9.3546e-04
# Epoch 26/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0010 - val_loss: 9.3627e-04
# Epoch 27/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0010 - val_loss: 9.5561e-04
# Epoch 28/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0010 - val_loss: 9.6902e-04
# Epoch 29/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.9795e-04 - val_loss: 9.7094e-04
# Epoch 30/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 31/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.8838e-04 - val_loss: 9.4194e-04
# Epoch 32/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0010 - val_loss: 9.5062e-04
# Epoch 33/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.8777e-04 - val_loss: 0.0011
# Epoch 34/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.9862e-04 - val_loss: 0.0010
# Epoch 35/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0010 - val_loss: 9.7079e-04
# Epoch 36/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.8808e-04 - val_loss: 9.8482e-04
# Epoch 37/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.9579e-04 - val_loss: 9.8526e-04
# Epoch 38/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.8466e-04 - val_loss: 9.5223e-04
# Epoch 39/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0010 - val_loss: 9.4233e-04
# Epoch 40/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0010 - val_loss: 9.4884e-04
# Epoch 41/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.8881e-04 - val_loss: 9.5852e-04
# Epoch 42/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.9427e-04 - val_loss: 9.3694e-04
# Epoch 43/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.8807e-04 - val_loss: 9.6504e-04
# Epoch 44/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.6262e-04 - val_loss: 9.7729e-04
# Epoch 45/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.7639e-04 - val_loss: 9.8219e-04
# Epoch 46/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.7838e-04 - val_loss: 9.8168e-04
# Epoch 47/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.7998e-04 - val_loss: 9.6982e-04
# Epoch 48/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.7139e-04 - val_loss: 9.7399e-04
# Epoch 49/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.6231e-04 - val_loss: 9.4604e-04
# Epoch 50/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.8144e-04 - val_loss: 9.4852e-04
# Epoch 51/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.8175e-04 - val_loss: 9.6435e-04
# Epoch 52/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.6033e-04 - val_loss: 9.4733e-04
# Epoch 53/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.7498e-04 - val_loss: 9.6917e-04
# Epoch 54/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.7504e-04 - val_loss: 9.4744e-04
# Epoch 55/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.6534e-04 - val_loss: 9.6827e-04
# Epoch 56/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.8091e-04 - val_loss: 9.5117e-04
# Epoch 57/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.7430e-04 - val_loss: 9.4175e-04
# Epoch 58/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.6461e-04 - val_loss: 9.5141e-04
# Epoch 59/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.7194e-04 - val_loss: 9.9319e-04
# Epoch 60/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.8689e-04 - val_loss: 9.4541e-04
# Epoch 61/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.5330e-04 - val_loss: 0.0010
# Epoch 62/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.5911e-04 - val_loss: 9.4695e-04
# Epoch 63/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.7920e-04 - val_loss: 9.8399e-04
# Epoch 64/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.7174e-04 - val_loss: 9.5473e-04
# Epoch 65/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.8879e-04 - val_loss: 9.5648e-04
# Epoch 66/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.6084e-04 - val_loss: 9.6829e-04
# Epoch 67/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.5972e-04 - val_loss: 9.9129e-04
# Epoch 68/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.5052e-04 - val_loss: 9.4847e-04
# Epoch 69/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.5004e-04 - val_loss: 9.7026e-04
# Epoch 70/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.4548e-04 - val_loss: 9.3379e-04
# Epoch 71/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.3403e-04 - val_loss: 9.5572e-04
# Epoch 72/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.4961e-04 - val_loss: 9.9645e-04
# Epoch 73/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.4818e-04 - val_loss: 9.7470e-04
# Epoch 74/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.4107e-04 - val_loss: 9.4413e-04
# Epoch 75/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.5006e-04 - val_loss: 9.6356e-04
# Epoch 76/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.4168e-04 - val_loss: 9.3871e-04
# Epoch 77/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.3979e-04 - val_loss: 9.4488e-04
# Epoch 78/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.4283e-04 - val_loss: 9.6932e-04
# Epoch 79/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.4669e-04 - val_loss: 9.7710e-04
# Epoch 80/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.2558e-04 - val_loss: 0.0010
# Epoch 81/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.4280e-04 - val_loss: 9.6357e-04
# Epoch 82/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.5382e-04 - val_loss: 9.3793e-04
# Epoch 83/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.3585e-04 - val_loss: 0.0010
# Epoch 84/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.2723e-04 - val_loss: 9.2322e-04
# Epoch 85/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.1901e-04 - val_loss: 9.9092e-04
# Epoch 86/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.2808e-04 - val_loss: 9.7831e-04
# Epoch 87/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.2316e-04 - val_loss: 9.4960e-04
# Epoch 88/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.2345e-04 - val_loss: 9.4116e-04
# Epoch 89/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.1952e-04 - val_loss: 9.6575e-04
# Epoch 90/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.3451e-04 - val_loss: 9.8807e-04
# Epoch 91/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.3157e-04 - val_loss: 9.4006e-04
# Epoch 92/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.2428e-04 - val_loss: 9.4513e-04
# Epoch 93/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.1451e-04 - val_loss: 0.0010
# Epoch 94/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.1570e-04 - val_loss: 9.7624e-04
# Epoch 95/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.1027e-04 - val_loss: 9.7328e-04
# Epoch 96/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.0695e-04 - val_loss: 9.5819e-04
# Epoch 97/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.2387e-04 - val_loss: 9.6239e-04
# Epoch 98/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.0213e-04 - val_loss: 9.6508e-04
# Epoch 99/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.1786e-04 - val_loss: 9.5812e-04
# Epoch 100/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.1119e-04 - val_loss: 9.3062e-04

# %% [markdown]
# # TASK #6: EVALUATE TRAINED DEEP LEARNING MODEL PERFORMANCE

# %%
epochs_hist.history.keys()
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
plt.plot(epochs_hist.history['loss'])
plt.plot(epochs_hist.history['val_loss'])
plt.title('Model Loss Progress During Training')
plt.xlabel('Epoch')
plt.ylabel('Training and Validation Loss')
plt.legend(['Training Loss', 'Validation Loss'])

# %%
# 'bedrooms','bathrooms','sqft_living','sqft_lot','floors', 'sqft_above', 'sqft_basement'
X_test_1 = np.array([[ 4, 3, 1960, 5000, 1, 2000, 3000 ]])

scaler_1 = MinMaxScaler()
X_test_scaled_1 = scaler_1.fit_transform(X_test_1)

y_predict_1 = model.predict(X_test_scaled_1)

y_predict_1 = scaler.inverse_transform(y_predict_1)
y_predict_1
# Out:
# 1/1 [==============================] - 0s 81ms/step
# array([[247839.25]], dtype=float32)

# %%
y_predict = model.predict(X_test)
plt.plot(y_test, y_predict, "^", color = 'r')
plt.xlabel('Model Predictions')
plt.ylabel('True Values')
# Out:
# 169/169 [==============================] - 0s 768us/step
# Text(0, 0.5, 'True Values')

# %%
y_predict_orig = scaler.inverse_transform(y_predict)
y_test_orig = scaler.inverse_transform(y_test)

# %%
plt.plot(y_test_orig, y_predict_orig, "^", color = 'r')
plt.xlabel('Model Predictions')
plt.ylabel('True Values')
plt.xlim(0, 5000000)
plt.ylim(0, 3000000)
# Out:
# (0.0, 3000000.0)

# %%
k = X_test.shape[1]
n = len(X_test)
n
# Out:
# 5404

# %%
k
# Out:
# 7

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from math import sqrt

RMSE = float(format(np.sqrt(mean_squared_error(y_test_orig, y_predict_orig)),'.3f'))
MSE = mean_squared_error(y_test_orig, y_predict_orig)
MAE = mean_absolute_error(y_test_orig, y_predict_orig)
r2 = r2_score(y_test_orig, y_predict_orig)
adj_r2 = 1-(1-r2)*(n-1)/(n-k-1)

print('RMSE =',RMSE, '\nMSE =',MSE, '\nMAE =',MAE, '\nR2 =', r2, '\nAdjusted R2 =', adj_r2)
# Out:
# RMSE = 225159.664
# MSE = 50696874133.6526
# MAE = 151620.42800182736
# R2 = 0.5519358156428102
# Adjusted R2 = 0.5513545611412349

# %% [markdown]
# # TASK #7. TRAIN AND EVALUATE A DEEP LEARNING MODEL WITH INCREASED NUMBER OF FEATURES (INDEPENDANT VARIABLES)

# %%
selected_features = ['bedrooms','bathrooms','sqft_living','sqft_lot','floors', 'sqft_above', 'sqft_basement', 'waterfront', 'view', 'condition', 'grade', 'sqft_above', 'yr_built', 
'yr_renovated', 'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15']

X = house_df[selected_features]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# %%
y = house_df['price']

# %%
y = y.values.reshape(-1,1)
y_scaled = scaler.fit_transform(y)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size = 0.25)

# %%
import tensorflow.keras
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(10, input_dim = 19, activation = 'relu'))
model.add(Dense(10, activation = 'relu'))
model.add(Dense(1, activation = 'linear'))

# %%
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
epochs_hist = model.fit(X_train, y_train, epochs = 100, batch_size = 50, verbose = 1, validation_split = 0.2)
# Out:
# Epoch 1/100
# 260/260 [==============================] - 1s 2ms/step - loss: 0.0027 - val_loss: 0.0017
# Epoch 2/100
# 260/260 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 3/100
# 260/260 [==============================] - 0s 1ms/step - loss: 9.0402e-04 - val_loss: 9.2205e-04
# Epoch 4/100
# 260/260 [==============================] - 0s 1ms/step - loss: 7.9087e-04 - val_loss: 8.3306e-04
# Epoch 5/100
# 260/260 [==============================] - 0s 1ms/step - loss: 7.2030e-04 - val_loss: 7.8253e-04
# Epoch 6/100
# 260/260 [==============================] - 0s 1ms/step - loss: 6.8807e-04 - val_loss: 7.4430e-04
# Epoch 7/100
# 260/260 [==============================] - 0s 1ms/step - loss: 6.5690e-04 - val_loss: 7.2105e-04
# Epoch 8/100
# 260/260 [==============================] - 0s 1ms/step - loss: 6.3907e-04 - val_loss: 7.2066e-04
# Epoch 9/100
# 260/260 [==============================] - 0s 1ms/step - loss: 6.1769e-04 - val_loss: 6.9339e-04
# Epoch 10/100
# 260/260 [==============================] - 0s 1ms/step - loss: 6.0066e-04 - val_loss: 6.5750e-04
# Epoch 11/100
# 260/260 [==============================] - 0s 1ms/step - loss: 5.7965e-04 - val_loss: 6.4784e-04
# Epoch 12/100
# 260/260 [==============================] - 0s 1ms/step - loss: 5.6552e-04 - val_loss: 6.3041e-04
# Epoch 13/100
# 260/260 [==============================] - 0s 1ms/step - loss: 5.4467e-04 - val_loss: 6.5693e-04
# Epoch 14/100
# 260/260 [==============================] - 0s 1ms/step - loss: 5.3040e-04 - val_loss: 5.8718e-04
# Epoch 15/100
# 260/260 [==============================] - 0s 1ms/step - loss: 5.1514e-04 - val_loss: 5.8137e-04
# Epoch 16/100
# 260/260 [==============================] - 0s 1ms/step - loss: 5.0640e-04 - val_loss: 5.5875e-04
# Epoch 17/100
# 260/260 [==============================] - 0s 1ms/step - loss: 4.9479e-04 - val_loss: 5.7891e-04
# Epoch 18/100
# 260/260 [==============================] - 0s 1ms/step - loss: 4.8654e-04 - val_loss: 5.3448e-04
# Epoch 19/100
# 260/260 [==============================] - 0s 1ms/step - loss: 4.6865e-04 - val_loss: 5.3217e-04
# Epoch 20/100
# 260/260 [==============================] - 0s 1ms/step - loss: 4.6120e-04 - val_loss: 5.1388e-04
# Epoch 21/100
# 260/260 [==============================] - 0s 1ms/step - loss: 4.5490e-04 - val_loss: 5.0421e-04
# Epoch 22/100
# 260/260 [==============================] - 0s 1ms/step - loss: 4.4809e-04 - val_loss: 4.8387e-04
# Epoch 23/100
# 260/260 [==============================] - 0s 1ms/step - loss: 4.3001e-04 - val_loss: 4.9009e-04
# Epoch 24/100
# 260/260 [==============================] - 0s 1ms/step - loss: 4.3659e-04 - val_loss: 5.0591e-04
# Epoch 25/100
# 260/260 [==============================] - 0s 1ms/step - loss: 4.2244e-04 - val_loss: 4.6932e-04
# Epoch 26/100
# 260/260 [==============================] - 0s 1ms/step - loss: 4.1489e-04 - val_loss: 4.7891e-04
# Epoch 27/100
# 260/260 [==============================] - 0s 1ms/step - loss: 4.0983e-04 - val_loss: 4.6142e-04
# Epoch 28/100
# 260/260 [==============================] - 0s 1ms/step - loss: 4.1167e-04 - val_loss: 4.9866e-04
# Epoch 29/100
# 260/260 [==============================] - 0s 1ms/step - loss: 4.0368e-04 - val_loss: 5.2237e-04
# Epoch 30/100
# 260/260 [==============================] - 0s 1ms/step - loss: 4.0112e-04 - val_loss: 4.4257e-04
# Epoch 31/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.9767e-04 - val_loss: 4.3726e-04
# Epoch 32/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.9601e-04 - val_loss: 4.4139e-04
# Epoch 33/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.8811e-04 - val_loss: 4.5012e-04
# Epoch 34/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.9011e-04 - val_loss: 4.6420e-04
# Epoch 35/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.8356e-04 - val_loss: 4.4184e-04
# Epoch 36/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.8211e-04 - val_loss: 4.4976e-04
# Epoch 37/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.8023e-04 - val_loss: 4.2086e-04
# Epoch 38/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.7317e-04 - val_loss: 4.0828e-04
# Epoch 39/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.7501e-04 - val_loss: 4.3550e-04
# Epoch 40/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.7386e-04 - val_loss: 4.4162e-04
# Epoch 41/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.6971e-04 - val_loss: 4.3703e-04
# Epoch 42/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.6664e-04 - val_loss: 4.3301e-04
# Epoch 43/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.6205e-04 - val_loss: 5.1680e-04
# Epoch 44/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.6080e-04 - val_loss: 3.9412e-04
# Epoch 45/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.6042e-04 - val_loss: 4.2062e-04
# Epoch 46/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.5367e-04 - val_loss: 4.2082e-04
# Epoch 47/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.5490e-04 - val_loss: 3.9775e-04
# Epoch 48/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.5440e-04 - val_loss: 4.4372e-04
# Epoch 49/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.5442e-04 - val_loss: 3.8350e-04
# Epoch 50/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.5342e-04 - val_loss: 3.9608e-04
# Epoch 51/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.4996e-04 - val_loss: 3.7713e-04
# Epoch 52/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.5435e-04 - val_loss: 4.3807e-04
# Epoch 53/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.5002e-04 - val_loss: 3.7898e-04
# Epoch 54/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.4130e-04 - val_loss: 3.8139e-04
# Epoch 55/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.3945e-04 - val_loss: 3.8930e-04
# Epoch 56/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.4134e-04 - val_loss: 3.7696e-04
# Epoch 57/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.3551e-04 - val_loss: 4.3458e-04
# Epoch 58/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.4206e-04 - val_loss: 3.9560e-04
# Epoch 59/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.4456e-04 - val_loss: 3.8564e-04
# Epoch 60/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.3694e-04 - val_loss: 3.7464e-04
# Epoch 61/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.3325e-04 - val_loss: 3.7514e-04
# Epoch 62/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.4073e-04 - val_loss: 4.1248e-04
# Epoch 63/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.4121e-04 - val_loss: 3.9518e-04
# Epoch 64/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.3969e-04 - val_loss: 3.7132e-04
# Epoch 65/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.3875e-04 - val_loss: 3.8078e-04
# Epoch 66/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.3048e-04 - val_loss: 3.8875e-04
# Epoch 67/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.3183e-04 - val_loss: 3.6746e-04
# Epoch 68/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.3393e-04 - val_loss: 3.7319e-04
# Epoch 69/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.2177e-04 - val_loss: 3.9264e-04
# Epoch 70/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.2964e-04 - val_loss: 3.7454e-04
# Epoch 71/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.2662e-04 - val_loss: 3.7768e-04
# Epoch 72/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.2267e-04 - val_loss: 3.6419e-04
# Epoch 73/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.2335e-04 - val_loss: 3.7598e-04
# Epoch 74/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.2438e-04 - val_loss: 3.7257e-04
# Epoch 75/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.1826e-04 - val_loss: 4.1115e-04
# Epoch 76/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.1873e-04 - val_loss: 4.1255e-04
# Epoch 77/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.3398e-04 - val_loss: 3.8712e-04
# Epoch 78/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.1645e-04 - val_loss: 3.6313e-04
# Epoch 79/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.2185e-04 - val_loss: 3.7748e-04
# Epoch 80/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.2019e-04 - val_loss: 3.8642e-04
# Epoch 81/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.1997e-04 - val_loss: 3.7182e-04
# Epoch 82/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.1790e-04 - val_loss: 3.7071e-04
# Epoch 83/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.2081e-04 - val_loss: 3.6819e-04
# Epoch 84/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.0945e-04 - val_loss: 3.8113e-04
# Epoch 85/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.1485e-04 - val_loss: 4.4495e-04
# Epoch 86/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.2530e-04 - val_loss: 3.6890e-04
# Epoch 87/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.1835e-04 - val_loss: 3.6519e-04
# Epoch 88/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.1669e-04 - val_loss: 3.5965e-04
# Epoch 89/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.0949e-04 - val_loss: 3.6725e-04
# Epoch 90/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.1957e-04 - val_loss: 4.1344e-04
# Epoch 91/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.2400e-04 - val_loss: 3.6087e-04
# Epoch 92/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.1650e-04 - val_loss: 3.5211e-04
# Epoch 93/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.1006e-04 - val_loss: 4.1903e-04
# Epoch 94/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.1268e-04 - val_loss: 3.6592e-04
# Epoch 95/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.1994e-04 - val_loss: 3.8671e-04
# Epoch 96/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.1429e-04 - val_loss: 3.9507e-04
# Epoch 97/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.0964e-04 - val_loss: 4.1712e-04
# Epoch 98/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.1040e-04 - val_loss: 3.6027e-04
# Epoch 99/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.0501e-04 - val_loss: 3.7584e-04
# Epoch 100/100
# 260/260 [==============================] - 0s 1ms/step - loss: 3.1407e-04 - val_loss: 3.5700e-04

# %%
plt.plot(epochs_hist.history['loss'])
plt.plot(epochs_hist.history['val_loss'])
plt.title('Model Loss Progress During Training')
plt.ylabel('Training and Validation Loss')
plt.xlabel('Epoch number')
plt.legend(['Training Loss', 'Validation Loss'])

# %%
y_predict = model.predict(X_test)
plt.plot(y_test, y_predict, "^", color = 'r')
plt.xlabel("Model Predictions")
plt.ylabel("True Value (ground Truth)")
plt.title('Linear Regression Predictions')
plt.show()
# Out:
# 169/169 [==============================] - 0s 659us/step

# %%
y_predict_orig = scaler.inverse_transform(y_predict)
y_test_orig = scaler.inverse_transform(y_test)

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from math import sqrt

RMSE = float(format(np.sqrt(mean_squared_error(y_test_orig, y_predict_orig)),'.3f'))
MSE = mean_squared_error(y_test_orig, y_predict_orig)
MAE = mean_absolute_error(y_test_orig, y_predict_orig)
r2 = r2_score(y_test_orig, y_predict_orig)
adj_r2 = 1-(1-r2)*(n-1)/(n-k-1)

print('RMSE =',RMSE, '\nMSE =',MSE, '\nMAE =',MAE, '\nR2 =', r2, '\nAdjusted R2 =', adj_r2)
# Out:
# RMSE = 136269.351
# MSE = 18569336009.672256
# MAE = 81563.43393999236
# R2 = 0.8508364953164009
# Adjusted R2 = 0.8506429918818595
